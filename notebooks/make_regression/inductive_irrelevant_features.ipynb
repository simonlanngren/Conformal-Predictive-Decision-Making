# %% [markdown]
# ## Summary
# - Inductive setting
# - Medium sized training set
# - More irrelevant features
# - CPDM better than BDT to cope with irrelevant featues

# %%
import sys
import os

# Get the absolute path of the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))

# Add it to sys.path if not already added
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.functions.data_generation import DataGeneration

synthetic_data = DataGeneration.generate_data(
    n_samples=10000,
    n_features=100,
    n_informative=5,
    relationship='make_regression',
    noise=0.8,
    random_state=2025
)

# %%
from src.main import Main

utility_config = {
    'threshold': 0.5,
    'tp': 1,
    'tn': 1,
    'fp': -10,
    'fn': 0
}

method_config = {
    'mode': "Inductive",
    'run_v1': False,
    'run_v2': True,
    'run_predictive': True,
}

data_config = {
    'data': synthetic_data,
    'n_runs': 100,
    'sample_size': 100,
    'test_size': 0.2,
    'cal_size': 0.4,
    'random_state': 2025
}

models_config = {
    'include_ridge': True,
    'include_knn': False,
    'include_krr': True,
    'include_bayes_ridge': True,
    'include_gp': False
}

plot_config = {
    'plot_distributions': True,
    'print_split': True,
    'plot_average_utility': True,
    'plot_cumulative_regret': True,
    'plot_confidence': 0.95
}

model_selection_config = {
    'n_splits': 5,
    'search_space_knn': {
        'n_neighbors': [1, 3, 5, 7, 10, 15, 20],
    },
    'search_space_ridge': {
        'alpha': [0.01, 0.1, 1.0, 10.0, 100.0]
    },
    'search_space_krr': {
        'alpha': [1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2, 1e3],
        'kernel__k1__constant_value': [ 1e-2, 1e-1, 1e0, 1e1, 1e2],
        'kernel__k2__length_scale': [1e-2, 1e-1, 1e0, 1e1, 1e2]
    }
}

main = Main(
    threshold=utility_config["threshold"],
    tp=utility_config["tp"],
    tn=utility_config["tn"],
    fp=utility_config["fp"],
    fn=utility_config["fn"]
)
main.run_experiment(
    mode=method_config["mode"],
    run_v1=method_config["run_v1"],
    run_v2=method_config["run_v2"],
    run_predictive=method_config["run_predictive"],

    data=data_config["data"],
    n_runs=data_config["n_runs"],
    sample_size=data_config["sample_size"],
    test_size=data_config["test_size"],
    cal_size=data_config["cal_size"],
    random_state=data_config["random_state"],

    include_ridge=models_config["include_ridge"],
    include_knn=models_config["include_knn"],
    include_krr=models_config["include_krr"],
    include_bayesian_ridge=models_config["include_bayes_ridge"],
    include_gp=models_config["include_gp"],

    plot_distributions=plot_config["plot_distributions"],
    print_split=plot_config["print_split"],
    plot_average_utility=plot_config["plot_average_utility"],
    plot_cumulative_regret=plot_config["plot_cumulative_regret"],
    plot_confidence=plot_config["plot_confidence"],

    n_splits=model_selection_config["n_splits"],
    search_space_knn=model_selection_config["search_space_knn"],
    search_space_ridge=model_selection_config["search_space_ridge"],
    search_space_krr=model_selection_config["search_space_krr"]
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 65
#      43 model_selection_config = {
#      44     'n_splits': 5,
#      45     'search_space_knn': {
#    (...)     55     }
#      56 }
#      58 main = Main(
#      59     threshold=utility_config["threshold"],
#      60     tp=utility_config["tp"],
#    (...)     63     fn=utility_config["fn"]
#      64 )
# ---> 65 main.run_experiment(
#      66     mode=method_config["mode"],
#      67     run_v1=method_config["run_v1"],
#      68     run_v2=method_config["run_v2"],
#      69     return_predictive=method_config["return_predictive"],
#      70
#      71     data=data_config["data"],
#      72     n_runs=data_config["n_runs"],
#      73     sample_size=data_config["sample_size"],
#      74     test_size=data_config["test_size"],
#      75     cal_size=data_config["cal_size"],
#      76     random_state=data_config["random_state"],
#      77
#      78     include_ridge=models_config["include_ridge"],
#      79     include_knn=models_config["include_knn"],
#      80     include_krr=models_config["include_krr"],
#      81     include_bayesian_ridge=models_config["include_bayes_ridge"],
#      82     include_gp=models_config["include_gp"],
#      83
#      84     plot_distributions=plot_config["plot_distributions"],
#      85     print_split=plot_config["print_split"],
#      86     plot_average_utility=plot_config["plot_average_utility"],
#      87     plot_cumulative_regret=plot_config["plot_cumulative_regret"],
#      88     plot_confidence=plot_config["plot_confidence"],
#      89
#      90     n_splits=model_selection_config["n_splits"],
#      91     search_space_knn=model_selection_config["search_space_knn"],
#      92     search_space_ridge=model_selection_config["search_space_ridge"],
#      93     search_space_krr=model_selection_config["search_space_krr"]
#      94 )
#
# TypeError: Main.run_experiment() got an unexpected keyword argument 'return_predictive'. Did you mean 'run_predictive'?
