# %%
import sys
import os

# Get the absolute path of the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Add it to sys.path if not already added
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.main import Main

# Parameters for data generation
df_params = {
    'N': 10000,
    'F': 20,
    'skewness': 8,
    'kurtosis_change': True,
    'kurtosis_scale': 5,
    'mixture': False,
    'bimodal_separation': 5,
    'scaled': True,
}

# Utility values for decision outcomes
utility_dict = {
    'tp': 10,
    'tn': 0,
    'fp': -5,
    'fn': -8,
}

# Size of subset to be drawn from dataset
subset_size = 100

# Data split ratios for training, testing, and calibration
datasplit_dict = {
    'train_test': 0.3,  # 30% of data initially goes to test+calibration
    'test_cal': 0.5,    # Split this evenly into test and calibration
}

# Instantiate and run Main class
main = Main(df_params, utility_dict, subset_size, datasplit_dict)
main.data_generation()
# Out:
# Distribution created with:
# Number of Samples: 10000
# Number of Features: 20
# Skewness: 8
# Kurtosis Change: True
# Bimodality: False
# Metrics for Generated Distribution:
# Mean: -0.0000
# Standard Deviation: 1.0001
# Skewness: 0.9569
# Kurtosis: 0.9196
#
# --------------------------------------------------
# Train set size: 70
# Test set size: 15
# Calibration set size: 15
# (array([[-0.81243217,  0.31353179, -0.98035079, ..., -0.6544797 ,
#          -1.1306587 ,  0.30663306],
#         [ 0.90459102,  1.78651858, -1.39459871, ...,  0.23750598,
#          -0.64817407, -1.0235319 ],
#         [-0.75770249,  0.2722365 , -0.69412577, ...,  0.31271701,
#          -1.06402323, -1.15079795],
#         ...,
#         [-0.58447752, -0.40321006,  0.57426049, ...,  1.73057989,
#          -1.02084964, -1.27714491],
#         [ 0.63951896, -0.9081295 , -0.08844284, ...,  0.55559453,
#           1.1259123 , -0.40126035],
#         [ 0.91453946,  0.56160539,  0.04544782, ..., -0.13539302,
# ...
